# %%
import os
import re
import json
import hashlib
import asyncio
import logging
from typing import List, Optional, Dict
from dataclasses import dataclass

# ✅ 替换为 OpenAI SDK (DeepSeek 兼容)
from openai import AsyncOpenAI
from tqdm.asyncio import tqdm_asyncio

# ================= 配置区域 =================
API_KEY = "sk-114514"  # 替换你的 DeepSeek API Key
BASE_URL = "https://api.deepseek.com" # DeepSeek 官方地址

# 模型选择：
# deepseek-chat (即 DeepSeek-V3, 推荐，速度快，文采好)
# deepseek-reasoner (即 DeepSeek-R1, 逻辑强，但作为文学重写可能略慢且贵)
MODEL_NAME = "deepseek-chat" 

# 【文件路径配置】
FILE_28_RAW = "hlm_28.txt"       # 待润色的后28回原始文件
TEMP_DIR = "temp_chapters_split" # 临时存放拆分后章节的目录
OUTPUT_DIR = "refined_chapters_pro_ds" # 输出目录改个名，区分一下
CACHE_FILE = "refiner_cache_ds.json"   # 缓存文件也区分一下

CHUNK_SIZE = 2000
CONCURRENCY_LIMIT = 3  # DeepSeek API 限速较为严格，如遇 429 请调低此数值 (如 2 或 3)

# ================= 黄金风格锚点 (Golden Anchors) =================
GOLDEN_SAMPLES = """
【范例一·人物神态（脂粉气）】
宝玉听了，此时心下早已明白了，也不答言，只嘻嘻的笑。黛玉道：“你也不用哄我。从今以后，我也不敢亲近二爷，二爷也全当没有我这么个人，便是。”说着，那泪珠儿早扑簌簌滚下来了。

【范例二·场景描写（富贵锦绣）】
只见入门便是曲折游廊，阶下石子漫成甬路。上面小小两三间房舍，一明两暗，里面都是合着地步打就的床几椅案。从里间房内又得一小门，出去则是后院，有大株梨花兼着芭蕉。

【范例三·叙事转折（苍凉感）】
且说那贾雨村此时官复原职，正春风得意，哪里记得当年的葫芦案？正是：身后有余忘缩手，眼前无路想回头。这日正坐堂，忽听有人击鼓，你道是谁？
"""

# %%
# ================= 日志配置 =================
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    datefmt="%H:%M:%S"
)
logger = logging.getLogger("RedRefiner-DS")

@dataclass
class SegmentTask:
    chapter_title: str
    index: int
    total: int
    text: str

class RedChamberEngine:
    def __init__(self, api_key: str, base_url: str, model_name: str):
        # ✅ 初始化 OpenAI 异步客户端
        self.client = AsyncOpenAI(api_key=api_key, base_url=base_url)
        self.model_name = model_name
        
        self.system_prompt = (
            "你是一位红学造诣极深的文学家，正在将《红楼梦》癸酉本的粗糙底稿，重写为曹雪芹前八十回的精美正文。\n"
            "【绝对禁令】：\n"
            "1. 严禁修改原剧情走向、人物关系和核心事件。你的工作是'润色'而非'改编'。\n"
            "2. 严禁出现现代词汇（如：情绪、心理、立刻、此时）。\n"
            "【风格要求】：\n"
            "1. 还原'脂粉气'与'书卷气'并存的白话文风。\n"
            "2. 对话要补全神态（冷笑、低头、拭泪）。\n"
            "3. 章节过渡使用'且说'、'不题'、'看官听说'等传统话术。"
        )
        
        self.cache = self._load_cache()

    def _load_cache(self) -> Dict[str, str]:
        if os.path.exists(CACHE_FILE):
            try:
                with open(CACHE_FILE, 'r', encoding='utf-8') as f:
                    return json.load(f)
            except:
                return {}
        return {}

    def _save_cache(self):
        with open(CACHE_FILE, 'w', encoding='utf-8') as f:
            json.dump(self.cache, f, ensure_ascii=False, indent=2)

    def _get_hash(self, text: str) -> str:
        return hashlib.md5(text.encode('utf-8')).hexdigest()

    def smart_split(self, text: str, limit: int) -> List[str]:
        raw_paragraphs = text.split('\n')
        segments = []
        current_chunk = []
        current_len = 0

        for para in raw_paragraphs:
            para = para.strip()
            if not para: continue
            
            # 保护对话和诗词不被切断
            is_dialogue_start = para.endswith("道：") or para.endswith("说道") or para.endswith("笑道")
            
            current_chunk.append(para)
            current_len += len(para)

            if current_len >= limit and not is_dialogue_start:
                segments.append("\n".join(current_chunk))
                current_chunk = []
                current_len = 0
        
        if current_chunk:
            segments.append("\n".join(current_chunk))
        return segments

    async def refine_segment_async(self, task: SegmentTask, semaphore: asyncio.Semaphore) -> Optional[str]:
        input_hash = self._get_hash(task.text)
        if input_hash in self.cache:
            return self.cache[input_hash]

        user_content = f"""
{GOLDEN_SAMPLES}

==================================================
【当前进度】：正在重写《{task.chapter_title}》的第 {task.index}/{task.total} 部分。

【原始底稿】：
{task.text}

【重写指令】：
请以此底稿为骨架，重塑血肉。保留所有情节，仅修改语言风格。
请直接输出重写后的正文，无需任何解释或前缀。
"""
        retries = 3
        async with semaphore:
            for attempt in range(retries):
                try:
                    # ✅ DeepSeek (OpenAI) 调用方式
                    response = await self.client.chat.completions.create(
                        model=self.model_name,
                        messages=[
                            {"role": "system", "content": self.system_prompt},
                            {"role": "user", "content": user_content}
                        ],
                        temperature=1.0, 
                        max_tokens=8192,
                        stream=False
                    )
                    
                    result_text = response.choices[0].message.content
                    if result_text:
                        self.cache[input_hash] = result_text
                        return result_text
                        
                except Exception as e:
                    wait_time = 2 ** attempt
                    logger.warning(f"[{task.chapter_title}-{task.index}] 重试({attempt+1}/{retries}): {e}")
                    await asyncio.sleep(wait_time)
            
            logger.error(f"[{task.chapter_title}-{task.index}] ❌ 彻底失败")
            return None

    async def process_chapter(self, file_path: str):
        if not os.path.exists(file_path): return

        filename = os.path.basename(file_path)
        title = filename.split('.')[0]
        output_file = os.path.join(OUTPUT_DIR, f"refined_{filename}")
        
        if os.path.exists(output_file):
            logger.info(f"⏩ 跳过已存在: {filename}")
            return

        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read()

        raw_segments = self.smart_split(content, CHUNK_SIZE)
        tasks = [SegmentTask(title, i+1, len(raw_segments), seg) for i, seg in enumerate(raw_segments)]

        logger.info(f"🚀 开始处理: {title} (共 {len(tasks)} 片段)")
        semaphore = asyncio.Semaphore(CONCURRENCY_LIMIT)
        
        results = await tqdm_asyncio.gather(
            *[self.refine_segment_async(t, semaphore) for t in tasks],
            desc=f"Refining {title}"
        )

        if None in results:
            logger.error(f"❌ {title} 存在失败片段，跳过保存。")
            return

        full_text = f"{title}\n\n" + "\n".join(results)
        with open(output_file, 'w', encoding='utf-8') as f:
            f.write(full_text)
        
        self._save_cache()
        logger.info(f"💾 {title} 保存成功。")

    async def run_batch(self, file_list: List[str]):
        if not os.path.exists(OUTPUT_DIR): os.makedirs(OUTPUT_DIR)
        for file_path in file_list:
            await self.process_chapter(file_path)

# ================= 核心辅助函数：拆分大文件（V3.1 终极修正版） =================
def split_big_file_to_temp(raw_file: str, output_dir: str) -> List[str]:
    """
    【V3.1 终极修正版】
    1. 使用正则行首匹配，解决“批语误切”问题。
    2. 加入【智能去重】，解决“重复标题导致文件名错位”问题。
    """
    if not os.path.exists(raw_file):
        logger.error(f"❌ 找不到源文件: {raw_file}")
        return []

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    with open(raw_file, 'r', encoding='utf-8') as f:
        content = f.read()

    # 正则：匹配行首的“第xx回”，且忽略正文中的引用
    pattern = re.compile(r"(^第[一二三四五六七八九十百]+回\s+.+?)(?=^第[一二三四五六七八九十百]+回|\Z)", re.DOTALL | re.MULTILINE)
    
    matches = list(pattern.finditer(content))
    generated_files = []
    
    # 【去重关键】
    seen_chapters = set()
    real_index = 0
    
    if not matches:
        logger.warning("⚠️ 未检测到标准回目，兜底处理。")
        out_path = os.path.join(output_dir, "chapter_full.txt")
        with open(out_path, "w", encoding='utf-8') as f: f.write(content)
        generated_files.append(out_path)
    else:
        logger.info(f"📖 扫描到 {len(matches)} 个片段，正在执行清洗去重...")
        for m in matches:
            chapter_content = m.group(1)
            first_line = chapter_content.strip().split('\n')[0]
            
            # 提取回目号（如“第九十六回”）用于查重
            chapter_num_match = re.search(r"(第[一二三四五六七八九十百]+回)", first_line)
            if not chapter_num_match: continue
            chapter_num = chapter_num_match.group(1)
            
            # 1. 查重
            if chapter_num in seen_chapters:
                logger.warning(f"🗑️ 丢弃重复/脚注片段: {first_line[:20]}...")
                continue
            
            # 2. 查空（过滤只有标题没有正文的废料）
            if len(chapter_content) < 50:
                logger.warning(f"🗑️ 丢弃过短片段: {first_line[:20]}...")
                continue
                
            seen_chapters.add(chapter_num)
            
            # 3. 文件名生成
            safe_name = re.sub(r'[\\/*?:"<>|]', "", first_line[:30]).strip()
            safe_name = safe_name.replace(" ", "_").replace("[^1]", "")
            
            fname = f"{real_index + 81:03d}_{safe_name}.txt"
            out_path = os.path.join(output_dir, fname)
            
            with open(out_path, "w", encoding='utf-8') as f:
                f.write(chapter_content)
            generated_files.append(out_path)
            real_index += 1
            
    return generated_files

# ================= 主流程 =================
async def main():
    if API_KEY.startswith("xxxxx"):
        print("❌ 请先填写 DeepSeek API Key")
        return

    # 1. 准备引擎
    engine = RedChamberEngine(API_KEY, BASE_URL, MODEL_NAME)

    # 2. 拆分原始文件（使用带去重的 V3.1 逻辑）
    chapter_files = split_big_file_to_temp(FILE_28_RAW, TEMP_DIR)
    
    if not chapter_files:
        print("❌ 没有可处理的文件。")
        return
        
    print(f"✅ 成功拆分出 {len(chapter_files)} 个有效章节，准备开始生成...")

    # 3. 批量执行
    await engine.run_batch(chapter_files)

# ✅ Jupyter Notebook 专用入口
if __name__ == "__main__":
    await main()
# Out:
# 10:51:32 - INFO - 📖 扫描到 33 个片段，正在执行清洗去重...
# 10:51:32 - WARNING - 🗑️ 丢弃过短片段: 第九十六回 贾宝玉参无知无识 花袭人信有...
# 10:51:32 - WARNING - 🗑️ 丢弃过短片段: 第一百二回 冷惜春甘伴青灯佛 洁妙玉泥陷...
# 10:51:32 - WARNING - 🗑️ 丢弃过短片段: 第一百三回 刘姥姥三进荣国府 贾巧姐二哭...
# 10:51:32 - WARNING - 🗑️ 丢弃过短片段: 第一百五回 薛宝钗借词含讽谏 王熙凤知命...
# 10:51:32 - WARNING - 🗑️ 丢弃过短片段: 第一百六回 孤倔王孙悬崖撒手 凄惶红袖秋...
# 10:51:32 - INFO - 🚀 开始处理: 081_第八十一回_惜昵近公子做良媒_讳笞罚丫鬟结恶党 (共 6 片段)
# ✅ 成功拆分出 28 个有效章节，准备开始生成...
# Refining 081_第八十一回_惜昵近公子做良媒_讳笞罚丫鬟结恶党:  17%|█▋        | 1/6 [00:00<00:00,  5.63it/s]10:51:32 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 081_第八十一回_惜昵近公子做良媒_讳笞罚丫鬟结恶党: 100%|██████████| 6/6 [00:11<00:00,  1.87s/it]
# 10:51:43 - INFO - 💾 081_第八十一回_惜昵近公子做良媒_讳笞罚丫鬟结恶党 保存成功。
# 10:51:43 - INFO - 🚀 开始处理: 082_第八十二回_王熙凤病求千翼方_林黛玉闷作十独吟 (共 5 片段)
# Refining 082_第八十二回_王熙凤病求千翼方_林黛玉闷作十独吟:   0%|          | 0/5 [00:00<?, ?it/s]10:51:43 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 082_第八十二回_王熙凤病求千翼方_林黛玉闷作十独吟: 100%|██████████| 5/5 [00:09<00:00,  1.93s/it]
# 10:51:53 - INFO - 💾 082_第八十二回_王熙凤病求千翼方_林黛玉闷作十独吟 保存成功。
# 10:51:53 - INFO - 🚀 开始处理: 083_第八十三回_史太君临终念子孙_王夫人膏肓托儿女 (共 4 片段)
# Refining 083_第八十三回_史太君临终念子孙_王夫人膏肓托儿女:   0%|          | 0/4 [00:00<?, ?it/s]10:51:53 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 083_第八十三回_史太君临终念子孙_王夫人膏肓托儿女: 100%|██████████| 4/4 [00:50<00:00, 12.52s/it]
# 10:52:43 - INFO - 💾 083_第八十三回_史太君临终念子孙_王夫人膏肓托儿女 保存成功。
# 10:52:43 - INFO - 🚀 开始处理: 084_第八十四回_薛宝钗弥望金玉缘_史湘云喜得如意郎 (共 5 片段)
# Refining 084_第八十四回_薛宝钗弥望金玉缘_史湘云喜得如意郎:   0%|          | 0/5 [00:00<?, ?it/s]10:52:43 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 084_第八十四回_薛宝钗弥望金玉缘_史湘云喜得如意郎: 100%|██████████| 5/5 [00:19<00:00,  3.89s/it]
# 10:53:02 - INFO - 💾 084_第八十四回_薛宝钗弥望金玉缘_史湘云喜得如意郎 保存成功。
# 10:53:02 - INFO - 🚀 开始处理: 085_第八十五回_痴王孙传信牵奇缘_惭妙尼避情乘游槎 (共 5 片段)
# Refining 085_第八十五回_痴王孙传信牵奇缘_惭妙尼避情乘游槎:   0%|          | 0/5 [00:00<?, ?it/s]10:53:03 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 10:53:03 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 10:53:03 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 085_第八十五回_痴王孙传信牵奇缘_惭妙尼避情乘游槎:  20%|██        | 1/5 [00:56<03:46, 56.67s/it]10:53:59 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 085_第八十五回_痴王孙传信牵奇缘_惭妙尼避情乘游槎:  40%|████      | 2/5 [01:01<01:18, 26.04s/it]10:54:04 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 085_第八十五回_痴王孙传信牵奇缘_惭妙尼避情乘游槎: 100%|██████████| 5/5 [02:06<00:00, 25.30s/it]
# 10:55:09 - INFO - 💾 085_第八十五回_痴王孙传信牵奇缘_惭妙尼避情乘游槎 保存成功。
# 10:55:09 - INFO - 🚀 开始处理: 086_第八十六回_挑正庶风月断佳偶_祭祖祠清明泣远嫁 (共 5 片段)
# Refining 086_第八十六回_挑正庶风月断佳偶_祭祖祠清明泣远嫁:   0%|          | 0/5 [00:00<?, ?it/s]10:55:09 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 10:55:09 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 10:55:09 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 086_第八十六回_挑正庶风月断佳偶_祭祖祠清明泣远嫁:  20%|██        | 1/5 [00:52<03:30, 52.71s/it]10:56:02 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 10:56:02 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 086_第八十六回_挑正庶风月断佳偶_祭祖祠清明泣远嫁: 100%|██████████| 5/5 [01:45<00:00, 21.03s/it]
# 10:56:54 - INFO - 💾 086_第八十六回_挑正庶风月断佳偶_祭祖祠清明泣远嫁 保存成功。
# 10:56:54 - INFO - 🚀 开始处理: 087_第八十七回_花柳质命断无情兽_绣户女自绝美韶华 (共 4 片段)
# Refining 087_第八十七回_花柳质命断无情兽_绣户女自绝美韶华:   0%|          | 0/4 [00:00<?, ?it/s]10:56:54 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 10:56:57 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 10:56:57 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 087_第八十七回_花柳质命断无情兽_绣户女自绝美韶华:  25%|██▌       | 1/4 [00:33<01:40, 33.56s/it]10:57:28 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 087_第八十七回_花柳质命断无情兽_绣户女自绝美韶华: 100%|██████████| 4/4 [01:31<00:00, 22.92s/it]
# 10:58:26 - INFO - 💾 087_第八十七回_花柳质命断无情兽_绣户女自绝美韶华 保存成功。
# 10:58:26 - INFO - 🚀 开始处理: 088_第八十八回_邢夫人执意寻舛错_王熙凤聪明误此生 (共 4 片段)
# Refining 088_第八十八回_邢夫人执意寻舛错_王熙凤聪明误此生:   0%|          | 0/4 [00:00<?, ?it/s]10:58:26 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 10:58:26 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 10:58:26 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 088_第八十八回_邢夫人执意寻舛错_王熙凤聪明误此生:  25%|██▌       | 1/4 [00:54<02:43, 54.51s/it]10:59:20 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 088_第八十八回_邢夫人执意寻舛错_王熙凤聪明误此生: 100%|██████████| 4/4 [01:46<00:00, 26.66s/it]
# 11:00:12 - INFO - 💾 088_第八十八回_邢夫人执意寻舛错_王熙凤聪明误此生 保存成功。
# 11:00:12 - INFO - 🚀 开始处理: 089_第八十九回_有情人欣遇赏心事_不良妾专煞良辰景 (共 4 片段)
# Refining 089_第八十九回_有情人欣遇赏心事_不良妾专煞良辰景:   0%|          | 0/4 [00:00<?, ?it/s]11:00:13 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:00:13 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:00:13 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 089_第八十九回_有情人欣遇赏心事_不良妾专煞良辰景:  25%|██▌       | 1/4 [00:25<01:17, 25.89s/it]11:00:38 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 089_第八十九回_有情人欣遇赏心事_不良妾专煞良辰景: 100%|██████████| 4/4 [01:24<00:00, 21.18s/it]
# 11:01:37 - INFO - 💾 089_第八十九回_有情人欣遇赏心事_不良妾专煞良辰景 保存成功。
# 11:01:37 - INFO - 🚀 开始处理: 090_第九十回_林黛玉嬉春待好音_贾元春托梦警天伦 (共 4 片段)
# Refining 090_第九十回_林黛玉嬉春待好音_贾元春托梦警天伦:   0%|          | 0/4 [00:00<?, ?it/s]11:01:37 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:01:37 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:01:37 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 090_第九十回_林黛玉嬉春待好音_贾元春托梦警天伦:  25%|██▌       | 1/4 [00:31<01:34, 31.56s/it]11:02:09 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 090_第九十回_林黛玉嬉春待好音_贾元春托梦警天伦: 100%|██████████| 4/4 [01:35<00:00, 23.77s/it]
# 11:03:12 - INFO - 💾 090_第九十回_林黛玉嬉春待好音_贾元春托梦警天伦 保存成功。
# 11:03:12 - INFO - 🚀 开始处理: 091_第九十一回_锦衣卫查抄荣宁府_御林军戒严大观园 (共 4 片段)
# Refining 091_第九十一回_锦衣卫查抄荣宁府_御林军戒严大观园:   0%|          | 0/4 [00:00<?, ?it/s]11:03:12 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:03:12 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:03:12 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 091_第九十一回_锦衣卫查抄荣宁府_御林军戒严大观园:  25%|██▌       | 1/4 [00:30<01:32, 30.88s/it]11:03:43 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 091_第九十一回_锦衣卫查抄荣宁府_御林军戒严大观园: 100%|██████████| 4/4 [01:21<00:00, 20.47s/it]
# 11:04:34 - INFO - 💾 091_第九十一回_锦衣卫查抄荣宁府_御林军戒严大观园 保存成功。
# 11:04:34 - INFO - 🚀 开始处理: 092_第九十二回_家宅乱恶子通强梁_世道艰道人连流寇 (共 5 片段)
# Refining 092_第九十二回_家宅乱恶子通强梁_世道艰道人连流寇:   0%|          | 0/5 [00:00<?, ?it/s]11:04:34 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:04:34 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:04:34 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 092_第九十二回_家宅乱恶子通强梁_世道艰道人连流寇:  20%|██        | 1/5 [00:12<00:50, 12.59s/it]11:04:47 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 092_第九十二回_家宅乱恶子通强梁_世道艰道人连流寇:  40%|████      | 2/5 [00:55<01:30, 30.17s/it]11:05:29 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 092_第九十二回_家宅乱恶子通强梁_世道艰道人连流寇: 100%|██████████| 5/5 [01:48<00:00, 21.80s/it]
# 11:06:23 - INFO - 💾 092_第九十二回_家宅乱恶子通强梁_世道艰道人连流寇 保存成功。
# 11:06:23 - INFO - 🚀 开始处理: 093_第九十三回_山雨近阊阖笼霭晦_风云喧末世漫尘烟 (共 4 片段)
# Refining 093_第九十三回_山雨近阊阖笼霭晦_风云喧末世漫尘烟:   0%|          | 0/4 [00:00<?, ?it/s]11:06:23 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:06:23 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:06:23 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 093_第九十三回_山雨近阊阖笼霭晦_风云喧末世漫尘烟:  25%|██▌       | 1/4 [00:54<02:42, 54.20s/it]11:07:17 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 093_第九十三回_山雨近阊阖笼霭晦_风云喧末世漫尘烟: 100%|██████████| 4/4 [01:45<00:00, 26.31s/it]
# 11:08:08 - INFO - 💾 093_第九十三回_山雨近阊阖笼霭晦_风云喧末世漫尘烟 保存成功。
# 11:08:08 - INFO - 🚀 开始处理: 094_第九十四回_骨肉泯良女落风尘_贵贱失恶奴劫浮财 (共 5 片段)
# Refining 094_第九十四回_骨肉泯良女落风尘_贵贱失恶奴劫浮财:   0%|          | 0/5 [00:00<?, ?it/s]11:08:09 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:08:09 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:08:09 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 094_第九十四回_骨肉泯良女落风尘_贵贱失恶奴劫浮财:  20%|██        | 1/5 [00:39<02:38, 39.56s/it]11:08:48 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 094_第九十四回_骨肉泯良女落风尘_贵贱失恶奴劫浮财:  40%|████      | 2/5 [00:53<01:13, 24.49s/it]11:09:02 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 094_第九十四回_骨肉泯良女落风尘_贵贱失恶奴劫浮财: 100%|██████████| 5/5 [01:48<00:00, 21.65s/it]
# 11:09:57 - INFO - 💾 094_第九十四回_骨肉泯良女落风尘_贵贱失恶奴劫浮财 保存成功。
# 11:09:57 - INFO - 🚀 开始处理: 095_第九十五回_水月庵龄官挞贾蔷_嶽神庙茜雪慰宝玉 (共 4 片段)
# Refining 095_第九十五回_水月庵龄官挞贾蔷_嶽神庙茜雪慰宝玉:   0%|          | 0/4 [00:00<?, ?it/s]11:09:57 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:09:57 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:09:57 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 095_第九十五回_水月庵龄官挞贾蔷_嶽神庙茜雪慰宝玉:  25%|██▌       | 1/4 [00:53<02:40, 53.64s/it]11:10:50 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 095_第九十五回_水月庵龄官挞贾蔷_嶽神庙茜雪慰宝玉: 100%|██████████| 4/4 [01:33<00:00, 23.49s/it]
# 11:11:31 - INFO - 💾 095_第九十五回_水月庵龄官挞贾蔷_嶽神庙茜雪慰宝玉 保存成功。
# 11:11:31 - INFO - 🚀 开始处理: 096_第九十六回_贾宝玉参无知无识_花袭人信有始有终 (共 4 片段)
# Refining 096_第九十六回_贾宝玉参无知无识_花袭人信有始有终:   0%|          | 0/4 [00:00<?, ?it/s]11:11:31 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:11:31 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:11:31 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 096_第九十六回_贾宝玉参无知无识_花袭人信有始有终:  25%|██▌       | 1/4 [00:50<02:31, 50.60s/it]11:12:21 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 096_第九十六回_贾宝玉参无知无识_花袭人信有始有终: 100%|██████████| 4/4 [01:47<00:00, 26.95s/it]
# 11:13:18 - INFO - 💾 096_第九十六回_贾宝玉参无知无识_花袭人信有始有终 保存成功。
# 11:13:18 - INFO - 🚀 开始处理: 097_第九十七回_鸳鸯女谮语泄天机_绛珠仙泪尽抛全生 (共 5 片段)
# Refining 097_第九十七回_鸳鸯女谮语泄天机_绛珠仙泪尽抛全生:   0%|          | 0/5 [00:00<?, ?it/s]11:13:19 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:13:19 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:13:19 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 097_第九十七回_鸳鸯女谮语泄天机_绛珠仙泪尽抛全生:  20%|██        | 1/5 [00:52<03:28, 52.04s/it]11:14:11 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 097_第九十七回_鸳鸯女谮语泄天机_绛珠仙泪尽抛全生:  40%|████      | 2/5 [00:52<01:05, 21.89s/it]11:14:11 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 097_第九十七回_鸳鸯女谮语泄天机_绛珠仙泪尽抛全生: 100%|██████████| 5/5 [01:44<00:00, 20.98s/it]
# 11:15:03 - INFO - 💾 097_第九十七回_鸳鸯女谮语泄天机_绛珠仙泪尽抛全生 保存成功。
# 11:15:03 - INFO - 🚀 开始处理: 098_第九十八回_系新绦嗟慰失意人_拾旧帕悲悼寂寞骨 (共 4 片段)
# Refining 098_第九十八回_系新绦嗟慰失意人_拾旧帕悲悼寂寞骨:   0%|          | 0/4 [00:00<?, ?it/s]11:15:03 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:15:03 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:15:03 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 098_第九十八回_系新绦嗟慰失意人_拾旧帕悲悼寂寞骨:  25%|██▌       | 1/4 [00:40<02:02, 40.92s/it]11:15:44 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 098_第九十八回_系新绦嗟慰失意人_拾旧帕悲悼寂寞骨: 100%|██████████| 4/4 [01:35<00:00, 23.85s/it]
# 11:16:39 - INFO - 💾 098_第九十八回_系新绦嗟慰失意人_拾旧帕悲悼寂寞骨 保存成功。
# 11:16:39 - INFO - 🚀 开始处理: 099_第九十九回_林黛玉还魂证前缘_贾宝玉展裘触旧情 (共 4 片段)
# Refining 099_第九十九回_林黛玉还魂证前缘_贾宝玉展裘触旧情:   0%|          | 0/4 [00:00<?, ?it/s]11:16:39 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:16:39 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:16:39 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 099_第九十九回_林黛玉还魂证前缘_贾宝玉展裘触旧情:  25%|██▌       | 1/4 [00:21<01:05, 21.70s/it]11:17:00 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 099_第九十九回_林黛玉还魂证前缘_贾宝玉展裘触旧情: 100%|██████████| 4/4 [01:18<00:00, 19.66s/it]
# 11:17:57 - INFO - 💾 099_第九十九回_林黛玉还魂证前缘_贾宝玉展裘触旧情 保存成功。
# 11:17:57 - INFO - 🚀 开始处理: 100_第一百回_邢岫烟魂断大庾岭_赵姨娘命丧平安州 (共 4 片段)
# Refining 100_第一百回_邢岫烟魂断大庾岭_赵姨娘命丧平安州:   0%|          | 0/4 [00:00<?, ?it/s]11:17:57 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:17:58 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:17:58 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 100_第一百回_邢岫烟魂断大庾岭_赵姨娘命丧平安州:  25%|██▌       | 1/4 [00:22<01:07, 22.59s/it]11:18:20 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 100_第一百回_邢岫烟魂断大庾岭_赵姨娘命丧平安州: 100%|██████████| 4/4 [01:17<00:00, 19.27s/it]
# 11:19:14 - INFO - 💾 100_第一百回_邢岫烟魂断大庾岭_赵姨娘命丧平安州 保存成功。
# 11:19:14 - INFO - 🚀 开始处理: 101_第一百一回_呆霸王惹祸牵旧案_悍妒妇作歹设新谋 (共 4 片段)
# Refining 101_第一百一回_呆霸王惹祸牵旧案_悍妒妇作歹设新谋:   0%|          | 0/4 [00:00<?, ?it/s]11:19:15 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:19:15 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:19:15 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 101_第一百一回_呆霸王惹祸牵旧案_悍妒妇作歹设新谋:  25%|██▌       | 1/4 [00:45<02:17, 45.76s/it]11:20:00 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 101_第一百一回_呆霸王惹祸牵旧案_悍妒妇作歹设新谋: 100%|██████████| 4/4 [01:43<00:00, 25.95s/it]
# 11:20:58 - INFO - 💾 101_第一百一回_呆霸王惹祸牵旧案_悍妒妇作歹设新谋 保存成功。
# 11:20:58 - INFO - 🚀 开始处理: 102_第一百二回_冷惜春甘伴青灯佛_洁妙玉泥陷瓜洲渡 (共 4 片段)
# Refining 102_第一百二回_冷惜春甘伴青灯佛_洁妙玉泥陷瓜洲渡:   0%|          | 0/4 [00:00<?, ?it/s]11:20:58 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:20:58 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:20:59 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 102_第一百二回_冷惜春甘伴青灯佛_洁妙玉泥陷瓜洲渡:  25%|██▌       | 1/4 [00:55<02:46, 55.53s/it]11:21:54 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 102_第一百二回_冷惜春甘伴青灯佛_洁妙玉泥陷瓜洲渡: 100%|██████████| 4/4 [01:28<00:00, 22.01s/it]
# 11:22:26 - INFO - 💾 102_第一百二回_冷惜春甘伴青灯佛_洁妙玉泥陷瓜洲渡 保存成功。
# 11:22:26 - INFO - 🚀 开始处理: 103_第一百三回_刘姥姥三进荣国府_贾巧姐二哭大观园 (共 4 片段)
# Refining 103_第一百三回_刘姥姥三进荣国府_贾巧姐二哭大观园:   0%|          | 0/4 [00:00<?, ?it/s]11:22:26 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:22:26 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:22:27 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 103_第一百三回_刘姥姥三进荣国府_贾巧姐二哭大观园:  25%|██▌       | 1/4 [00:21<01:04, 21.57s/it]11:22:48 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 103_第一百三回_刘姥姥三进荣国府_贾巧姐二哭大观园: 100%|██████████| 4/4 [01:19<00:00, 19.80s/it]
# 11:23:46 - INFO - 💾 103_第一百三回_刘姥姥三进荣国府_贾巧姐二哭大观园 保存成功。
# 11:23:46 - INFO - 🚀 开始处理: 104_第一百四回_毒中毒薛姨妈添病_计上计夏金桂焚身 (共 4 片段)
# Refining 104_第一百四回_毒中毒薛姨妈添病_计上计夏金桂焚身:   0%|          | 0/4 [00:00<?, ?it/s]11:23:46 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:23:46 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:23:46 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 104_第一百四回_毒中毒薛姨妈添病_计上计夏金桂焚身:  25%|██▌       | 1/4 [00:42<02:06, 42.24s/it]11:24:28 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 104_第一百四回_毒中毒薛姨妈添病_计上计夏金桂焚身: 100%|██████████| 4/4 [01:36<00:00, 24.05s/it]
# 11:25:22 - INFO - 💾 104_第一百四回_毒中毒薛姨妈添病_计上计夏金桂焚身 保存成功。
# 11:25:22 - INFO - 🚀 开始处理: 105_第一百五回_薛宝钗借词含讽谏_王熙凤知命强英雄 (共 3 片段)
# Refining 105_第一百五回_薛宝钗借词含讽谏_王熙凤知命强英雄:   0%|          | 0/3 [00:00<?, ?it/s]11:25:22 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:25:22 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:25:22 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 105_第一百五回_薛宝钗借词含讽谏_王熙凤知命强英雄: 100%|██████████| 3/3 [01:00<00:00, 20.26s/it]
# 11:26:23 - INFO - 💾 105_第一百五回_薛宝钗借词含讽谏_王熙凤知命强英雄 保存成功。
# 11:26:23 - INFO - 🚀 开始处理: 106_第一百六回_孤倔王孙悬崖撒手_凄惶红袖秋千传情 (共 4 片段)
# Refining 106_第一百六回_孤倔王孙悬崖撒手_凄惶红袖秋千传情:   0%|          | 0/4 [00:00<?, ?it/s]11:26:23 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:26:23 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:26:23 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 106_第一百六回_孤倔王孙悬崖撒手_凄惶红袖秋千传情:  25%|██▌       | 1/4 [00:39<01:57, 39.00s/it]11:27:02 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 106_第一百六回_孤倔王孙悬崖撒手_凄惶红袖秋千传情: 100%|██████████| 4/4 [01:31<00:00, 22.93s/it]
# 11:27:54 - INFO - 💾 106_第一百六回_孤倔王孙悬崖撒手_凄惶红袖秋千传情 保存成功。
# 11:27:54 - INFO - 🚀 开始处理: 107_第一百七回_史湘云诉前尘旧梦_贾宝玉淡后事今生 (共 3 片段)
# Refining 107_第一百七回_史湘云诉前尘旧梦_贾宝玉淡后事今生:   0%|          | 0/3 [00:00<?, ?it/s]11:27:54 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:27:54 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:27:55 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 107_第一百七回_史湘云诉前尘旧梦_贾宝玉淡后事今生: 100%|██████████| 3/3 [00:59<00:00, 19.87s/it]
# 11:28:54 - INFO - 💾 107_第一百七回_史湘云诉前尘旧梦_贾宝玉淡后事今生 保存成功。
# 11:28:54 - INFO - 🚀 开始处理: 108_第一百八回_情不情僧遭逢穷途_幻中幻境展演情榜 (共 4 片段)
# Refining 108_第一百八回_情不情僧遭逢穷途_幻中幻境展演情榜:   0%|          | 0/4 [00:00<?, ?it/s]11:28:54 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:28:54 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 11:28:54 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 108_第一百八回_情不情僧遭逢穷途_幻中幻境展演情榜:  25%|██▌       | 1/4 [00:19<00:58, 19.45s/it]11:29:13 - INFO - HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Refining 108_第一百八回_情不情僧遭逢穷途_幻中幻境展演情榜: 100%|██████████| 4/4 [01:03<00:00, 15.77s/it]
# 11:29:57 - INFO - 💾 108_第一百八回_情不情僧遭逢穷途_幻中幻境展演情榜 保存成功。

# %%
import re
import os

# ================= 配置 =================
TARGET_FILE = "hlm_28.txt"
START_INDEX = 81

def simulate_split_clean(file_path):
    print(f"🔍 正在扫描文件: {file_path}")
    
    with open(file_path, 'r', encoding='utf-8') as f:
        content = f.read()

    # 1. 正则匹配
    pattern = re.compile(r"(^第[一二三四五六七八九十百]+回\s+.+?)(?=^第[一二三四五六七八九十百]+回|\Z)", re.DOTALL | re.MULTILINE)
    matches = list(pattern.finditer(content))
    
    print(f"📖 原始匹配: {len(matches)} 个片段")
    print(f"🛡️ 启动 V3.1 智能去重清洗...")
    print("=" * 60)

    # 2. 智能去重逻辑 (模拟 V3.1 核心算法)
    seen_chapters = set()
    real_index = 0
    clean_files = []

    for m in matches:
        chapter_content = m.group(1)
        first_line = chapter_content.strip().split('\n')[0]
        
        # 提取 "第xx回"
        chapter_num_match = re.search(r"(第[一二三四五六七八九十百]+回)", first_line)
        if not chapter_num_match: continue
        chapter_num = chapter_num_match.group(1)

        # --- 核心判断 ---
        if chapter_num in seen_chapters:
            print(f"🗑️ [剔除重复] {first_line[:30]}...") # 打印被剔除的垃圾
            continue
            
        if len(chapter_content) < 50:
            print(f"🗑️ [剔除过短] {first_line[:30]}...")
            continue
        # ----------------

        seen_chapters.add(chapter_num)
        
        # 生成预览文件名
        safe_name = re.sub(r'[\\/*?:"<>|]', "", first_line[:30]).strip()
        safe_name = safe_name.replace(" ", "_").replace("[^1]", "") # 清洗掉脚注标
        
        final_filename = f"{real_index + START_INDEX:03d}_{safe_name}.txt"
        clean_files.append(final_filename)
        real_index += 1

    print("=" * 60)
    print(f"✅ 清洗后剩余: {len(clean_files)} 个章节 (目标值: 28)")
    print("-" * 20)
    for f in clean_files:
        print(f)

if __name__ == "__main__":
    if os.path.exists(TARGET_FILE):
        simulate_split_clean(TARGET_FILE)
    else:
        print(f"找不到 {TARGET_FILE}")
# Out:
# 🔍 正在扫描文件: hlm_28.txt
# 📖 原始匹配: 33 个片段
# 🛡️ 启动 V3.1 智能去重清洗...
# ============================================================
# 🗑️ [剔除过短] 第九十六回 贾宝玉参无知无识 花袭人信有始有终...
# 🗑️ [剔除过短] 第一百二回 冷惜春甘伴青灯佛 洁妙玉泥陷瓜洲渡...
# 🗑️ [剔除过短] 第一百三回 刘姥姥三进荣国府 贾巧姐二哭大观园...
# 🗑️ [剔除过短] 第一百五回 薛宝钗借词含讽谏 王熙凤知命强英雄...
# 🗑️ [剔除过短] 第一百六回 孤倔王孙悬崖撒手 凄惶红袖秋千传情...
# ============================================================
# ✅ 清洗后剩余: 28 个章节 (目标值: 28)
# --------------------
# 081_第八十一回_惜昵近公子做良媒_讳笞罚丫鬟结恶党.txt
# 082_第八十二回_王熙凤病求千翼方_林黛玉闷作十独吟.txt
# 083_第八十三回_史太君临终念子孙_王夫人膏肓托儿女.txt
# 084_第八十四回_薛宝钗弥望金玉缘_史湘云喜得如意郎.txt
# 085_第八十五回_痴王孙传信牵奇缘_惭妙尼避情乘游槎.txt
# 086_第八十六回_挑正庶风月断佳偶_祭祖祠清明泣远嫁.txt
# 087_第八十七回_花柳质命断无情兽_绣户女自绝美韶华.txt
# 088_第八十八回_邢夫人执意寻舛错_王熙凤聪明误此生.txt
# 089_第八十九回_有情人欣遇赏心事_不良妾专煞良辰景.txt
# 090_第九十回_林黛玉嬉春待好音_贾元春托梦警天伦.txt
# 091_第九十一回_锦衣卫查抄荣宁府_御林军戒严大观园.txt
# 092_第九十二回_家宅乱恶子通强梁_世道艰道人连流寇.txt
# 093_第九十三回_山雨近阊阖笼霭晦_风云喧末世漫尘烟.txt
# 094_第九十四回_骨肉泯良女落风尘_贵贱失恶奴劫浮财.txt
# 095_第九十五回_水月庵龄官挞贾蔷_嶽神庙茜雪慰宝玉.txt
# 096_第九十六回_贾宝玉参无知无识_花袭人信有始有终.txt
# 097_第九十七回_鸳鸯女谮语泄天机_绛珠仙泪尽抛全生.txt
# 098_第九十八回_系新绦嗟慰失意人_拾旧帕悲悼寂寞骨.txt
# 099_第九十九回_林黛玉还魂证前缘_贾宝玉展裘触旧情.txt
# 100_第一百回_邢岫烟魂断大庾岭_赵姨娘命丧平安州.txt
# 101_第一百一回_呆霸王惹祸牵旧案_悍妒妇作歹设新谋.txt
# 102_第一百二回_冷惜春甘伴青灯佛_洁妙玉泥陷瓜洲渡.txt
# 103_第一百三回_刘姥姥三进荣国府_贾巧姐二哭大观园.txt
# 104_第一百四回_毒中毒薛姨妈添病_计上计夏金桂焚身.txt
# 105_第一百五回_薛宝钗借词含讽谏_王熙凤知命强英雄.txt
# 106_第一百六回_孤倔王孙悬崖撒手_凄惶红袖秋千传情.txt
# 107_第一百七回_史湘云诉前尘旧梦_贾宝玉淡后事今生.txt
# 108_第一百八回_情不情僧遭逢穷途_幻中幻境展演情榜.txt

# %%
import os
import datetime

# ================= 配置区域 =================
source_dir = "refined_chapters_pro_ds"
output_file = "【修改版】红楼梦_后二十八回_全本.txt"
github_link = "https://github.com/Republic1024"
# ===========================================

# 获取所有txt文件并按文件名排序（非常重要！否则章节会乱）
# 过滤掉非 .txt 文件，防止读取系统隐藏文件
files = sorted([f for f in os.listdir(source_dir) if f.endswith(".txt")])

print(f"检测到 {len(files)} 个章节文件，开始合并...")

with open(output_file, "w", encoding="utf-8") as outfile:
    # 1. 写入正文
    for filename in files:
        filepath = os.path.join(source_dir, filename)
        with open(filepath, "r", encoding="utf-8") as infile:
            content = infile.read()
            # 写入章节分隔符和内容
            outfile.write(f"\n\n{'='*30}\n{filename}\n{'='*30}\n\n")
            outfile.write(content)
            print(f"已合并: {filename}")

    # 2. 写入末尾版权声明 (Copyright)
    current_year = datetime.datetime.now().year
    copyright_text = f"""
\n\n
{'#'*50}
# Generated by AI Red Chamber Engine (DeepSeek V3)
# Project Maintainer: Republic
# GitHub: {github_link}
# Copyright © {current_year} Republic. All Rights Reserved.
{'#'*50}
"""
    outfile.write(copyright_text)

print(f"\n✅ 合并完成！全书已保存至：{output_file}")
print(f"🔗 已添加版权链接：{github_link}")
# Out:
# 检测到 28 个章节文件，开始合并...
# 已合并: refined_081_第八十一回_惜昵近公子做良媒_讳笞罚丫鬟结恶党.txt
# 已合并: refined_082_第八十二回_王熙凤病求千翼方_林黛玉闷作十独吟.txt
# 已合并: refined_083_第八十三回_史太君临终念子孙_王夫人膏肓托儿女.txt
# 已合并: refined_084_第八十四回_薛宝钗弥望金玉缘_史湘云喜得如意郎.txt
# 已合并: refined_085_第八十五回_痴王孙传信牵奇缘_惭妙尼避情乘游槎.txt
# 已合并: refined_086_第八十六回_挑正庶风月断佳偶_祭祖祠清明泣远嫁.txt
# 已合并: refined_087_第八十七回_花柳质命断无情兽_绣户女自绝美韶华.txt
# 已合并: refined_088_第八十八回_邢夫人执意寻舛错_王熙凤聪明误此生.txt
# 已合并: refined_089_第八十九回_有情人欣遇赏心事_不良妾专煞良辰景.txt
# 已合并: refined_090_第九十回_林黛玉嬉春待好音_贾元春托梦警天伦.txt
# 已合并: refined_091_第九十一回_锦衣卫查抄荣宁府_御林军戒严大观园.txt
# 已合并: refined_092_第九十二回_家宅乱恶子通强梁_世道艰道人连流寇.txt
# 已合并: refined_093_第九十三回_山雨近阊阖笼霭晦_风云喧末世漫尘烟.txt
# 已合并: refined_094_第九十四回_骨肉泯良女落风尘_贵贱失恶奴劫浮财.txt
# 已合并: refined_095_第九十五回_水月庵龄官挞贾蔷_嶽神庙茜雪慰宝玉.txt
# 已合并: refined_096_第九十六回_贾宝玉参无知无识_花袭人信有始有终.txt
# 已合并: refined_097_第九十七回_鸳鸯女谮语泄天机_绛珠仙泪尽抛全生.txt
# 已合并: refined_098_第九十八回_系新绦嗟慰失意人_拾旧帕悲悼寂寞骨.txt
# 已合并: refined_099_第九十九回_林黛玉还魂证前缘_贾宝玉展裘触旧情.txt
# 已合并: refined_100_第一百回_邢岫烟魂断大庾岭_赵姨娘命丧平安州.txt
# 已合并: refined_101_第一百一回_呆霸王惹祸牵旧案_悍妒妇作歹设新谋.txt
# 已合并: refined_102_第一百二回_冷惜春甘伴青灯佛_洁妙玉泥陷瓜洲渡.txt
# 已合并: refined_103_第一百三回_刘姥姥三进荣国府_贾巧姐二哭大观园.txt
# 已合并: refined_104_第一百四回_毒中毒薛姨妈添病_计上计夏金桂焚身.txt
# 已合并: refined_105_第一百五回_薛宝钗借词含讽谏_王熙凤知命强英雄.txt
# 已合并: refined_106_第一百六回_孤倔王孙悬崖撒手_凄惶红袖秋千传情.txt
# 已合并: refined_107_第一百七回_史湘云诉前尘旧梦_贾宝玉淡后事今生.txt
# 已合并: refined_108_第一百八回_情不情僧遭逢穷途_幻中幻境展演情榜.txt
#
# ✅ 合并完成！全书已保存至：【修改版】红楼梦_后二十八回_全本.txt
# 🔗 已添加版权链接：https://github.com/Republic1024

# %%
# !jupyter nbconvert --to html main-deepseek.ipynb
# Out:
# [NbConvertApp] Converting notebook main-deepseek.ipynb to html
# [NbConvertApp] Writing 356032 bytes to main-deepseek.html
